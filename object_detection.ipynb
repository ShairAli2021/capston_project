# %%
# !pip install gradio==3.45.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 70.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 12.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.3/298.3 kB 37.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 39.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 11.2 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi
# Out:
# Thu Nov  9 11:13:53 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics==8.0.20
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 20.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# # Install **YOLOv8** *italicized text*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/project
# Out:
# /content/drive/MyDrive/project

# %%
# %cd /content/drive/MyDrive/project
model=YOLO('yolov8m.pt')
# Out:
# ...
# /content/drive/MyDrive/project
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 188MB/s]

# %%
# %cd /content/drive/MyDrive/project
model=YOLO('yolov8s.pt')
# Out:
# /content/drive/MyDrive/project

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# # Custom ***Training***

# %%
# %cd /content/drive/MyDrive/project
model.train(data="/content/drive/MyDrive/project/data.yaml" , epochs=100)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# /content/drive/MyDrive/project
# ...

# %%
model=YOLO("/content/drive/MyDrive/project/runs/detect/train4/weights/best.pt")

# %%
model=YOLO("/content/drive/MyDrive/project/runs/detect/train2/weights/best.pt")

# %%
model.predict("/content/drive/MyDrive/project/data/test/images", save =True,save_txt=True)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
# Results saved to runs/detect/predict3
# 60 labels saved to runs/detect/predict3/labels
# [Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([2, 6])
#  dtype: torch.float32
#   + tensor([[7.97000e+02, 6.60000e+02, 1.35000e+03, 1.08500e+03, 8.63382e-01, 1.00000e+00],
#          [3.18000e+02, 3.79000e+02, 1.51700e+03, 1.11400e+03, 8.17263e-01, 0.00000e+00]], device='cuda:0'),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([2, 6])
#  dtype: torch.float32
#   + tensor([[3.32000e+02, 2.14000e+02, 1.45400e+03, 8.55000e+02, 8.34638e-01, 0.00000e+00],
#          [7.02000e+02, 5.01000e+02, 1.25400e+03, 8.36000e+02, 8.17159e-01, 1.00000e+00]], device='cuda:0'),
# ...

# %%
Image(filename='/content/drive/MyDrive/project/runs/detect/train4/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/project/runs/detect/predict3/person5_bacteria_19.jpeg', width=600)

# %%
Image(filename='/content/drive/MyDrive/project/runs/detect/train/train_batch0.jpg', width=600)

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/drive/MyDrive/project/runs/detect/train/results.csv')

# %%
data.head()
# Out:
#                      epoch           train/box_loss           train/cls_loss  \
# 0                        0                   2.3146                   3.7588
# 1                        1                   1.9347                   3.5997
# 2                        2                   1.5530                   3.3777
# 3                        3                   1.4930                   2.9465
# 4                        4                   1.4806                   2.2792
#
#             train/dfl_loss     metrics/precision(B)  ...  \
# 0                   2.4861                  0.00331  ...
# 1                   2.1703                  0.00451  ...
# 2                   1.8253                  0.00376  ...
# 3                   1.8015                  1.00000  ...
# 4                   1.7318                  0.45155  ...
#
#               val/cls_loss             val/dfl_loss                   lr/pg0  \
# 0                   4.0554                   3.6158                 0.090100
# ...

# %%
Image(filename='/content/drive/MyDrive/project/runs/detect/train/results.png', width=600)

# %%
import gradio as gr

# %%
# !pip install utils

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-8775d651dbb3> in <cell line: 3>()
#       1 import torch
#       2
# ----> 3 from utils.general import check_img_size, non_max_suppression
#       4 import cv2
#       5
#
# ModuleNotFoundError: No module named 'utils.general'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
iface.launch(debug='True', share="True")
# Out:
# Rerunning server... use `close()` to stop if you need to change `launch()` parameters.
# ----
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://8b4d2120b22f8c380e.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-98706c2a7053> in <cell line: 1>()
# ----> 1 iface.launch(debug='True', share="True")
#
# ...

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# %cd /content/drive/MyDrive/project
model1 = YOLO("yolov8m-seg.pt")
# Out:
# /content/drive/MyDrive/project

# %%
# %cd /content/drive/MyDrive/project
model1.train(data="/content/drive/MyDrive/project/data.yaml" , epochs=70)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
